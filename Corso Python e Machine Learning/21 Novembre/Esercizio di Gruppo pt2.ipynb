# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('IMBD Movie Dataset.csv')
df
# Out:
#             id                    title  vote_average  vote_count    status  \
# 0        27205                Inception         8.364       34495  Released
# 1       157336             Interstellar         8.417       32571  Released
# 2          155          The Dark Knight         8.512       30619  Released
# 3        19995                   Avatar         7.573       29815  Released
# 4        24428             The Avengers         7.710       29166  Released
# ...        ...                      ...           ...         ...       ...
# 432290  732467         One Pandemic Day         0.000           0  Released
# 432291  732477  The Men Who Speak Gayle         0.000           0  Released
# 432292  732485               Conversion         0.000           0  Released
# 432293  732486           Shukran Habibi         0.000           0  Released
# 432294  732491      Go Crazy with Crazy         0.000           0  Released
#
#        release_date     revenue  runtime  adult  \
# ...

# %%
df.drop(['id', 'backdrop_path', 'tconst', 'homepage'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432295 entries, 0 to 432294
# Data columns (total 28 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    432295 non-null  int64
#  1   title                 432295 non-null  object
#  2   vote_average          432295 non-null  float64
#  3   vote_count            432295 non-null  int64
#  4   status                432295 non-null  object
#  5   release_date          414562 non-null  object
#  6   revenue               432295 non-null  int64
#  7   runtime               432295 non-null  int64
#  8   adult                 432295 non-null  bool
#  9   backdrop_path         183573 non-null  object
#  10  budget                432295 non-null  int64
#  11  homepage              54111 non-null   object
#  12  tconst                432295 non-null  object
#  13  original_language     432295 non-null  object
# ...
